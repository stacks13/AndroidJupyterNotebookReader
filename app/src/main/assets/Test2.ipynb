# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Haberman's Data
# **The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.**
# (Columns: Four colmns
# Age
# Op_Year
# axil_nodes
# Surv_status )

# %% [markdown]
# ## Attribute Information:
#
# Age of patient at time of operation (numerical)
#
# Patient's year of operation (year - 1900, numerical)
#
# Number of positive axillary nodes detected (numerical)
#
# Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year

# %%
data = pd.read_csv("haberman.csv",names=['Age','Op_Year','Axil_nodes','Survival_time'])

# %%
data['Survival_time'].map({1:'high',2:'low'}).astype('category')
# Out:
# 0      high
# 1      high
# 2      high
# 3      high
# 4      high
# 5      high
# 6      high
# 7       low
# 8       low
# 9      high
# 10     high
# 11     high
# 12     high
# 13     high
# 14     high
# 15     high
# 16     high
# 17     high
# 18     high
# 19     high
# 20     high
# 21     high
# 22     high
# 23     high
# 24      low
# 25     high
# 26     high
# 27     high
# 28     high
# 29     high
#        ...
# 276    high
# 277    high
# 278    high
# 279    high
# 280    high
# 281     low
# 282    high
# 283    high
# 284    high
# 285     low
# 286     low
# 287    high
# 288    high
# 289    high
# 290    high
# 291    high
# 292    high
# 293     low
# 294    high
# 295    high
# 296    high
# 297    high
# 298    high
# 299     low
# 300    high
# 301    high
# 302    high
# 303    high
# 304     low
# 305     low
# Name: Survival_time, Length: 306, dtype: category
# Categories (2, object): [high, low]

# %% [markdown]
# *We have the dataframe ready as 'data'. We set the labels of columns as above*

# %%
data.shape
# Out:
# (306, 4)

# %% [markdown]
# *The given data has 306 datapoints and 4 attributes(as described)*

# %%
data.columns
# Out:
# Index(['Age', 'Op_Year', 'Axil_nodes', 'Survival_time'], dtype='object')

# %%
data['Survival_time'].value_counts()
# Out:
# 1    225
# 2     81
# Name: Survival_time, dtype: int64

# %% [markdown]
# *Since, the people surviving more than 5 yrs is more than those who don't, the data is unbalanced*

# %% [markdown]
# *Which factors can affect the survival rate?*

# %%
sns.set_style("whitegrid")
sns.pairplot(data, hue="Survival_time", height=4)
plt.show()

# %% [markdown]
# *The data is not linearly separable*

# %%
sns.FacetGrid(data, hue="Survival_time", height=10) \
   .map(sns.distplot, "Op_Year") \
   .add_legend()
plt.show()

# %%
sns.boxplot(x='Op_Year',y='Age', data=data)
plt.show()

# %%
data['Age'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-9e76307c40ab> in <module>
# ----> 1 data['Age'].value_counts().sort_keys()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sort_keys'

# %%
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf)


counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=20, 
                                  density = True)
pdf = counts/(sum(counts))
plt.plot(bin_edges[1:],pdf);

plt.show();
